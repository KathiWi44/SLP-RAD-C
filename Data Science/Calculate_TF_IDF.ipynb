# %%
import os
import re
import numpy as np
import pandas as pd
from math import log

# %%
df = pd.read_csv('../PROCESS-V1/dem-info.csv')
df.head()
# Out:
#          Record-ID TrainOrDev Class  Gender Age  Converted-MMSE
# 0  Process-rec-001      train   MCI    male  62            25.0
# 1  Process-rec-002        dev   MCI    male  61            25.0
# 2  Process-rec-003      train   MCI  female  62            29.0
# 3  Process-rec-004        dev   MCI  female  67            29.0
# 4  Process-rec-005      train   MCI    male  65            27.0

# %%
# fix 66* string value in Age column
# df['Age'].value_counts()

df['Class'].value_counts()
def load_process(path):
    df = pd.read_csv(f'{path}/dem-info.csv')
    # fix 66* string value in Age column
    df['Age'] = df['Age'].apply(lambda x: x.replace('66*', '66'))
    df['Age'] = df['Age'].astype(int)
    # get_file_names
    for ext in ["CTD", "PFT", 'SFT']:
        df[f'{ext}_wav'] = f'{path}/' + df['Record-ID'] + '/' + df['Record-ID'] + f'__{ext}.wav'
        df[f'{ext}_txt'] = f'{path}/' + df['Record-ID'] + '/' + df['Record-ID'] + f'__{ext}.txt'

    # fix 66* string value in Age column
    df_train = df.loc[df['TrainOrDev'] == 'train']
    df_dev = df.loc[df['TrainOrDev'] == 'dev']
    return df_train, df_dev

# %%
def calculate_tf_idf(texts):
    """
    Berechnet die Term Frequency (TF) und Inverse Document Frequency (IDF) für eine Sammlung von Texten.

    Parameter:
        texts (list of str): Eine Liste von Texten, in denen die Häufigkeit der Wörter analysiert wird.

    Rückgabe:
        tf (list of dict): Liste von Dictionaries, die die TF-Werte pro Dokument enthalten.
        idf (dict): Dictionary, das die IDF-Werte für alle Wörter enthält.
    """
    # Tokenisierung der Texte
    tokenized_texts = [re.findall(r'\b\w+\b', text.lower()) for text in texts]

    # Berechnung der TF
    tf = []
    for tokens in tokenized_texts:
        word_counts = {}
        total_words = len(tokens)
        for word in tokens:
            word_counts[word] = word_counts.get(word, 0) + 1
        tf.append({word: count / total_words for word, count in word_counts.items()})

    # Berechnung der IDF
    doc_count = len(tokenized_texts)
    word_doc_counts = {}
    for tokens in tokenized_texts:
        unique_words = set(tokens)
        for word in unique_words:
            word_doc_counts[word] = word_doc_counts.get(word, 0) + 1

    idf = {word: log(doc_count / (1 + count)) for word, count in word_doc_counts.items()}

    return tf, idf

# %%
def process_text_files(df, text_column):
    """
    Liest Textdateien ein, berechnet TF und IDF und fügt die Ergebnisse dem DataFrame hinzu.

    Parameter:
        df (pd.DataFrame): DataFrame mit Informationen zu Textdateien.
        text_column (str): Spaltenname, der die Textdateipfade enthält.

    Rückgabe:
        pd.DataFrame: Aktualisierter DataFrame mit TF und IDF-Informationen.
    """
    # Texte aus den Dateien lesen
    texts = []
    for path in df[text_column]:
        if os.path.exists(path):
            with open(path, 'r', encoding='utf-8') as file:
                texts.append(file.read())
        else:
            texts.append("")

    # Berechnung von TF und IDF
    tf, idf = calculate_tf_idf(texts)

    # Ergebnisse in den DataFrame einfügen
    df['TF'] = tf
    df['IDF'] = [idf] * len(df)

    return df

# %%
# CTD_txt_train
result_df_train = process_text_files(df_train, 'CTD_txt')
final_columns = [ "Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_train = result_df_train[final_columns]
result_df_train
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 0    Process-rec-001      train       MCI    male            25.0
# 2    Process-rec-003      train       MCI  female            29.0
# 4    Process-rec-005      train       MCI    male            27.0
# 5    Process-rec-006      train  Dementia    male            26.0
# 8    Process-rec-009      train        HC  female             NaN
# ..               ...        ...       ...     ...             ...
# 152  Process-rec-153      train        HC    male            28.0
# 153  Process-rec-154      train        HC  female            30.0
# 154  Process-rec-155      train        HC    male            29.0
# 155  Process-rec-156      train  Dementia    male            26.0
# 156  Process-rec-157      train        HC    male            28.0
#
#                                                     TF  \
# 0    {'pat': 0.0091324200913242, 'but': 0.004566210...
# 2    {'pat': 0.006493506493506494, '3': 0.006493506...
# 4    {'pat': 0.020833333333333332, '50s': 0.0208333...
# 5    {'pat': 0.0072992700729927005, '1': 0.02189781...
# 8    {'pat': 0.0053475935828877, '2': 0.00534759358...
# ..                                                 ...
# 152  {'pat': 0.008333333333333333, 'the': 0.075, 's...
# 153  {'pat': 0.004149377593360996, 'i': 0.029045643...
# 154  {'pat': 0.010869565217391304, 'little': 0.0108...
# 155  {'pat': 0.015873015873015872, '3': 0.015873015...
# 156  {'pat': 0.0035211267605633804, '3': 0.00704225...
#
#                                                    IDF
# 0    {'really': 1.8177349556313156, 'amusing': 4.06...
# 2    {'really': 1.8177349556313156, 'amusing': 4.06...
# 4    {'really': 1.8177349556313156, 'amusing': 4.06...
# 5    {'really': 1.8177349556313156, 'amusing': 4.06...
# 8    {'really': 1.8177349556313156, 'amusing': 4.06...
# ..                                                 ...
# 152  {'really': 1.8177349556313156, 'amusing': 4.06...
# 153  {'really': 1.8177349556313156, 'amusing': 4.06...
# 154  {'really': 1.8177349556313156, 'amusing': 4.06...
# 155  {'really': 1.8177349556313156, 'amusing': 4.06...
# 156  {'really': 1.8177349556313156, 'amusing': 4.06...
#
# [117 rows x 7 columns]

# %%
result_df_train.to_csv("TF-IDF_CTD_train.csv", index = False)

# %%
# CTD_txt_dev
result_df_dev = process_text_files(df_dev, 'CTD_txt')
final_columns = [ "Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_dev = result_df_dev[final_columns]
result_df_dev
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 1    Process-rec-002        dev       MCI    male            25.0
# 3    Process-rec-004        dev       MCI  female            29.0
# 6    Process-rec-007        dev        HC    male             NaN
# 7    Process-rec-008        dev       MCI  female            25.0
# 15   Process-rec-016        dev  Dementia  female             NaN
# 20   Process-rec-021        dev       MCI    male             NaN
# 21   Process-rec-022        dev  Dementia    male            27.0
# 31   Process-rec-032        dev       MCI    male             NaN
# 32   Process-rec-033        dev       MCI  female             NaN
# 34   Process-rec-035        dev  Dementia    male            27.0
# 35   Process-rec-036        dev        HC  female             NaN
# 41   Process-rec-042        dev        HC  female             NaN
# 45   Process-rec-046        dev        HC    male             NaN
# 49   Process-rec-050        dev       MCI    male            19.0
# 54   Process-rec-055        dev       MCI  female            27.0
# 60   Process-rec-061        dev        HC    male             NaN
# 63   Process-rec-064        dev        HC    male             NaN
# 68   Process-rec-069        dev        HC  female             NaN
# 74   Process-rec-075        dev        HC    male            29.0
# 75   Process-rec-076        dev        HC    male            30.0
# 77   Process-rec-078        dev       MCI  female             NaN
# 79   Process-rec-080        dev       MCI  female             NaN
# 82   Process-rec-083        dev        HC  female             NaN
# 84   Process-rec-085        dev  Dementia    male            29.0
# 87   Process-rec-088        dev       MCI    male            27.0
# 92   Process-rec-093        dev       MCI  female             NaN
# 103  Process-rec-104        dev       MCI    male             NaN
# 109  Process-rec-110        dev        HC    male             NaN
# 111  Process-rec-112        dev        HC  female             NaN
# 116  Process-rec-117        dev       MCI    male             NaN
# 119  Process-rec-120        dev        HC  female            30.0
# 121  Process-rec-122        dev        HC    male             NaN
# 128  Process-rec-129        dev        HC    male            30.0
# 129  Process-rec-130        dev        HC    male             NaN
# 137  Process-rec-138        dev        HC  female             NaN
# 140  Process-rec-141        dev        HC  female             NaN
# 143  Process-rec-144        dev       MCI  female             NaN
# 148  Process-rec-149        dev        HC    male            27.0
# 149  Process-rec-150        dev        HC    male            30.0
# 151  Process-rec-152        dev        HC  female            29.0
#
#                                                     TF  \
# 1    {'pat': 0.011363636363636364, '4': 0.011363636...
# 3    {'pat': 0.005917159763313609, 'a': 0.029585798...
# 6    {'pat': 0.0045662100456621, 'washing': 0.00456...
# 7    {'pat': 0.008403361344537815, '3': 0.016806722...
# 15   {'pat': 0.006535947712418301, '2': 0.006535947...
# 20   {'pat': 0.018518518518518517, 'there': 0.01851...
# 21   {'pat': 0.014285714285714285, '2': 0.014285714...
# 31   {'pat': 0.006896551724137931, '6': 0.006896551...
# 32   {'pat': 0.0064516129032258064, 'a': 0.05806451...
# 34   {'pat': 0.011235955056179775, '1': 0.044943820...
# 35   {'pat': 0.0036900369003690036, 'ok': 0.0036900...
# 41   {'pat': 0.007352941176470588, 'um': 0.00735294...
# 45   {'pat': 0.018867924528301886, '2': 0.018867924...
# 49   {'pat': 0.011695906432748537, 'oh': 0.01169590...
# 54   {'pat': 0.002028397565922921, '1': 0.006085192...
# 60   {'pat': 0.006535947712418301, 'there': 0.01960...
# 63   {'pat': 0.007352941176470588, 'children': 0.00...
# 68   {'pat': 0.00847457627118644, 'so': 0.008474576...
# 74   {'pat': 0.007352941176470588, '2': 0.007352941...
# 75   {'pat': 0.0035971223021582736, 'so': 0.0035971...
# 77   {'pat': 0.018518518518518517, '1': 0.055555555...
# 79   {'pat': 0.006289308176100629, '2': 0.006289308...
# 82   {'pat': 0.004347826086956522, 'goodness': 0.00...
# 84   {'pat': 0.0036231884057971015, 'ok': 0.0036231...
# 87   {'pat': 0.004545454545454545, '2': 0.009090909...
# 92   {'pat': 0.007936507936507936, 'um': 0.11111111...
# 103  {'pat': 0.011494252873563218, '1': 0.034482758...
# 109  {'pat': 0.002890173410404624, 'ok': 0.00289017...
# 111  {'pat': 0.002890173410404624, 'um': 0.02890173...
# 116  {'pat': 0.015625, '1': 0.03125, 'second': 0.03...
# 119  {'pat': 0.006756756756756757, '4': 0.006756756...
# 121  {'pat': 0.010752688172043012, 'i': 0.043010752...
# 128  {'pat': 0.005208333333333333, 'it': 0.01041666...
# 129  {'pat': 0.008403361344537815, 'ok': 0.00840336...
# 137  {'pat': 0.0070921985815602835, 'the': 0.063829...
# 140  {'pat': 0.01282051282051282, 'mum': 0.01282051...
# 143  {'pat': 0.008333333333333333, '4': 0.008333333...
# 148  {'pat': 0.011111111111111112, 'er': 0.06666666...
# 149  {'pat': 0.0049261083743842365, 'ok': 0.0049261...
# 151  {'pat': 0.004338394793926247, '3': 0.002169197...
#
#                                                    IDF
# 1    {'jar': 0.13353139262452257, 'is': 0.077961541...
# 3    {'jar': 0.13353139262452257, 'is': 0.077961541...
# 6    {'jar': 0.13353139262452257, 'is': 0.077961541...
# 7    {'jar': 0.13353139262452257, 'is': 0.077961541...
# 15   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 20   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 21   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 31   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 32   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 34   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 35   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 41   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 45   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 49   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 54   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 60   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 63   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 68   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 74   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 75   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 77   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 79   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 82   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 84   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 87   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 92   {'jar': 0.13353139262452257, 'is': 0.077961541...
# 103  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 109  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 111  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 116  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 119  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 121  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 128  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 129  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 137  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 140  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 143  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 148  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 149  {'jar': 0.13353139262452257, 'is': 0.077961541...
# 151  {'jar': 0.13353139262452257, 'is': 0.077961541...

# %%
result_df_dev.to_csv("TF-IDF_CTD_dev.csv", index = False)

# %%
# PFT_txt_train
result_df_dev = process_text_files(df_train, 'PFT_txt')
final_columns = ["Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_train = result_df_train[final_columns]
result_df_train
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 0    Process-rec-001      train       MCI    male            25.0
# 2    Process-rec-003      train       MCI  female            29.0
# 4    Process-rec-005      train       MCI    male            27.0
# 5    Process-rec-006      train  Dementia    male            26.0
# 8    Process-rec-009      train        HC  female             NaN
# ..               ...        ...       ...     ...             ...
# 152  Process-rec-153      train        HC    male            28.0
# 153  Process-rec-154      train        HC  female            30.0
# 154  Process-rec-155      train        HC    male            29.0
# 155  Process-rec-156      train  Dementia    male            26.0
# 156  Process-rec-157      train        HC    male            28.0
#
#                                                     TF  \
# 0    {'pat': 0.0091324200913242, 'but': 0.004566210...
# 2    {'pat': 0.006493506493506494, '3': 0.006493506...
# 4    {'pat': 0.020833333333333332, '50s': 0.0208333...
# 5    {'pat': 0.0072992700729927005, '1': 0.02189781...
# 8    {'pat': 0.0053475935828877, '2': 0.00534759358...
# ..                                                 ...
# 152  {'pat': 0.008333333333333333, 'the': 0.075, 's...
# 153  {'pat': 0.004149377593360996, 'i': 0.029045643...
# 154  {'pat': 0.010869565217391304, 'little': 0.0108...
# 155  {'pat': 0.015873015873015872, '3': 0.015873015...
# 156  {'pat': 0.0035211267605633804, '3': 0.00704225...
#
#                                                    IDF
# 0    {'really': 1.8177349556313156, 'amusing': 4.06...
# 2    {'really': 1.8177349556313156, 'amusing': 4.06...
# 4    {'really': 1.8177349556313156, 'amusing': 4.06...
# 5    {'really': 1.8177349556313156, 'amusing': 4.06...
# 8    {'really': 1.8177349556313156, 'amusing': 4.06...
# ..                                                 ...
# 152  {'really': 1.8177349556313156, 'amusing': 4.06...
# 153  {'really': 1.8177349556313156, 'amusing': 4.06...
# 154  {'really': 1.8177349556313156, 'amusing': 4.06...
# 155  {'really': 1.8177349556313156, 'amusing': 4.06...
# 156  {'really': 1.8177349556313156, 'amusing': 4.06...
#
# [117 rows x 7 columns]

# %%
result_df_train.to_csv("TF-IDF_PFT_train.csv", index = False)

# %%
# PFT_txt_dev
result_df_dev = process_text_files(df_dev, 'PFT_txt')
final_columns = ["Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_dev = result_df_dev[final_columns]
result_df_dev
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 1    Process-rec-002        dev       MCI    male            25.0
# 3    Process-rec-004        dev       MCI  female            29.0
# 6    Process-rec-007        dev        HC    male             NaN
# 7    Process-rec-008        dev       MCI  female            25.0
# 15   Process-rec-016        dev  Dementia  female             NaN
# 20   Process-rec-021        dev       MCI    male             NaN
# 21   Process-rec-022        dev  Dementia    male            27.0
# 31   Process-rec-032        dev       MCI    male             NaN
# 32   Process-rec-033        dev       MCI  female             NaN
# 34   Process-rec-035        dev  Dementia    male            27.0
# 35   Process-rec-036        dev        HC  female             NaN
# 41   Process-rec-042        dev        HC  female             NaN
# 45   Process-rec-046        dev        HC    male             NaN
# 49   Process-rec-050        dev       MCI    male            19.0
# 54   Process-rec-055        dev       MCI  female            27.0
# 60   Process-rec-061        dev        HC    male             NaN
# 63   Process-rec-064        dev        HC    male             NaN
# 68   Process-rec-069        dev        HC  female             NaN
# 74   Process-rec-075        dev        HC    male            29.0
# 75   Process-rec-076        dev        HC    male            30.0
# 77   Process-rec-078        dev       MCI  female             NaN
# 79   Process-rec-080        dev       MCI  female             NaN
# 82   Process-rec-083        dev        HC  female             NaN
# 84   Process-rec-085        dev  Dementia    male            29.0
# 87   Process-rec-088        dev       MCI    male            27.0
# 92   Process-rec-093        dev       MCI  female             NaN
# 103  Process-rec-104        dev       MCI    male             NaN
# 109  Process-rec-110        dev        HC    male             NaN
# 111  Process-rec-112        dev        HC  female             NaN
# 116  Process-rec-117        dev       MCI    male             NaN
# 119  Process-rec-120        dev        HC  female            30.0
# 121  Process-rec-122        dev        HC    male             NaN
# 128  Process-rec-129        dev        HC    male            30.0
# 129  Process-rec-130        dev        HC    male             NaN
# 137  Process-rec-138        dev        HC  female             NaN
# 140  Process-rec-141        dev        HC  female             NaN
# 143  Process-rec-144        dev       MCI  female             NaN
# 148  Process-rec-149        dev        HC    male            27.0
# 149  Process-rec-150        dev        HC    male            30.0
# 151  Process-rec-152        dev        HC  female            29.0
#
#                                                     TF  \
# 1    {'pat': 0.027777777777777776, '1': 0.111111111...
# 3    {'pat': 0.016129032258064516, 'plank': 0.01612...
# 6    {'pat': 0.058823529411764705, 'place': 0.05882...
# 7    {'pat': 0.017857142857142856, '2': 0.160714285...
# 15   {'pat': 0.02040816326530612, '2': 0.0816326530...
# 20   {'pat': 0.011494252873563218, '3': 0.011494252...
# 21   {'pat': 0.025, '3': 0.05, 'seconds': 0.15, 'po...
# 31   {'pat': 0.056818181818181816, '1': 0.034090909...
# 32   {'pat': 0.017857142857142856, '2': 0.107142857...
# 34   {'pat': 0.04225352112676056, 'perfect': 0.0281...
# 35   {'pat': 0.028169014084507043, 'picked': 0.0281...
# 41   {'pat': 0.02127659574468085, 'plaster': 0.0212...
# 45   {'pat': 0.02857142857142857, 'pea': 0.02857142...
# 49   {'oth': 0.11428571428571428, 'p': 0.1142857142...
# 54   {'pat': 0.02040816326530612, 'person': 0.02040...
# 60   {'pat': 0.014084507042253521, 'pop': 0.0140845...
# 63   {'pat': 0.0196078431372549, 'er': 0.1372549019...
# 68   {'pat': 0.020833333333333332, 'pig': 0.0208333...
# 74   {'pat': 0.022222222222222223, 'play': 0.022222...
# 75   {'pat': 0.013333333333333334, '1': 0.106666666...
# 77   {'pat': 0.047619047619047616, '2': 0.047619047...
# 79   {'pat': 0.012658227848101266, 'i': 0.063291139...
# 82   {'pat': 0.014285714285714285, 'play': 0.028571...
# 84   {'pat': 0.018867924528301886, '4': 0.056603773...
# 87   {'pat': 0.02631578947368421, 'pot': 0.02631578...
# 92   {'pat': 0.01694915254237288, 'um': 0.288135593...
# 103  {'pat': 0.027777777777777776, '1': 0.111111111...
# 109  {'pat': 0.016666666666666666, 'pepper': 0.0166...
# 111  {'pat': 0.01818181818181818, 'pen': 0.01818181...
# 116  {'pat': 0.03225806451612903, 'pea': 0.03225806...
# 119  {'pat': 0.03389830508474576, '2': 0.0169491525...
# 121  {'pat': 0.030303030303030304, 'presentation': ...
# 128  {'oth': 0.12962962962962962, 'pansies': 0.0370...
# 129  {'pat': 0.01282051282051282, 'peter': 0.012820...
# 137  {'pat': 0.02631578947368421, 'buzzer': 0.05263...
# 140  {'pat': 0.015625, 'petrol': 0.015625, 'paint':...
# 143  {'pat': 0.02040816326530612, '3': 0.0408163265...
# 148  {'pat': 0.015384615384615385, 'buzzer': 0.0307...
# 149  {'pat': 0.021739130434782608, 'buzzer': 0.0434...
# 151  {'pat': 0.01694915254237288, 'people': 0.03389...
#
#                                                    IDF
# 1    {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 3    {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 6    {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 7    {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 15   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 20   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 21   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 31   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 32   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 34   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 35   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 41   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 45   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 49   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 54   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 60   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 63   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 68   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 74   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 75   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 77   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 79   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 82   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 84   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 87   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 92   {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 103  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 109  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 111  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 116  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 119  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 121  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 128  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 129  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 137  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 140  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 143  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 148  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 149  {'5': 0.7985076962177716, 'pilot': 2.302585092...
# 151  {'5': 0.7985076962177716, 'pilot': 2.302585092...

# %%
result_df_dev.to_csv("TF-IDF_PFT_dev.csv", index = False)

# %%
# SFT_txt_train
result_df_train = process_text_files(df_train, 'SFT_txt')
final_columns = ["Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_train = result_df_train[final_columns]
result_df_train
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 0    Process-rec-001      train       MCI    male            25.0
# 2    Process-rec-003      train       MCI  female            29.0
# 4    Process-rec-005      train       MCI    male            27.0
# 5    Process-rec-006      train  Dementia    male            26.0
# 8    Process-rec-009      train        HC  female             NaN
# ..               ...        ...       ...     ...             ...
# 152  Process-rec-153      train        HC    male            28.0
# 153  Process-rec-154      train        HC  female            30.0
# 154  Process-rec-155      train        HC    male            29.0
# 155  Process-rec-156      train  Dementia    male            26.0
# 156  Process-rec-157      train        HC    male            28.0
#
#                                                     TF  \
# 0    {'pat': 0.024390243902439025, '3': 0.146341463...
# 2    {'pat': 0.017543859649122806, 'cow': 0.0175438...
# 4    {'pat': 0.015151515151515152, 'dog': 0.0151515...
# 5    {'pat': 0.029411764705882353, 'dog': 0.0294117...
# 8    {'pat': 0.025, 'lion': 0.025, 'tiger': 0.025, ...
# ..                                                 ...
# 152  {'pat': 0.008695652173913044, 'um': 0.14782608...
# 153  {'pat': 0.022727272727272728, 'cat': 0.0340909...
# 154  {'pat': 0.014084507042253521, 'horse': 0.01408...
# 155  {'pat': 0.024390243902439025, 'pig': 0.0731707...
# 156  {'pat': 0.0196078431372549, 'ooh': 0.019607843...
#
#                                                    IDF
# 0    {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 2    {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 4    {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 5    {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 8    {'mosquito': 3.6635616461296463, 'giraffe': 0....
# ..                                                 ...
# 152  {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 153  {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 154  {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 155  {'mosquito': 3.6635616461296463, 'giraffe': 0....
# 156  {'mosquito': 3.6635616461296463, 'giraffe': 0....
#
# [117 rows x 7 columns]

# %%
result_df_train.to_csv("TF-IDF_SFT_train.csv", index = False)

# %%
# SFT_txt_dev
result_df_dev = process_text_files(df_dev, 'SFT_txt')
final_columns = ["Record-ID", "TrainOrDev", "Class", "Gender", "Converted-MMSE", "TF", "IDF"]
result_df_dev = result_df_dev[final_columns]
result_df_dev
# Out:
#            Record-ID TrainOrDev     Class  Gender  Converted-MMSE  \
# 1    Process-rec-002        dev       MCI    male            25.0
# 3    Process-rec-004        dev       MCI  female            29.0
# 6    Process-rec-007        dev        HC    male             NaN
# 7    Process-rec-008        dev       MCI  female            25.0
# 15   Process-rec-016        dev  Dementia  female             NaN
# 20   Process-rec-021        dev       MCI    male             NaN
# 21   Process-rec-022        dev  Dementia    male            27.0
# 31   Process-rec-032        dev       MCI    male             NaN
# 32   Process-rec-033        dev       MCI  female             NaN
# 34   Process-rec-035        dev  Dementia    male            27.0
# 35   Process-rec-036        dev        HC  female             NaN
# 41   Process-rec-042        dev        HC  female             NaN
# 45   Process-rec-046        dev        HC    male             NaN
# 49   Process-rec-050        dev       MCI    male            19.0
# 54   Process-rec-055        dev       MCI  female            27.0
# 60   Process-rec-061        dev        HC    male             NaN
# 63   Process-rec-064        dev        HC    male             NaN
# 68   Process-rec-069        dev        HC  female             NaN
# 74   Process-rec-075        dev        HC    male            29.0
# 75   Process-rec-076        dev        HC    male            30.0
# 77   Process-rec-078        dev       MCI  female             NaN
# 79   Process-rec-080        dev       MCI  female             NaN
# 82   Process-rec-083        dev        HC  female             NaN
# 84   Process-rec-085        dev  Dementia    male            29.0
# 87   Process-rec-088        dev       MCI    male            27.0
# 92   Process-rec-093        dev       MCI  female             NaN
# 103  Process-rec-104        dev       MCI    male             NaN
# 109  Process-rec-110        dev        HC    male             NaN
# 111  Process-rec-112        dev        HC  female             NaN
# 116  Process-rec-117        dev       MCI    male             NaN
# 119  Process-rec-120        dev        HC  female            30.0
# 121  Process-rec-122        dev        HC    male             NaN
# 128  Process-rec-129        dev        HC    male            30.0
# 129  Process-rec-130        dev        HC    male             NaN
# 137  Process-rec-138        dev        HC  female             NaN
# 140  Process-rec-141        dev        HC  female             NaN
# 143  Process-rec-144        dev       MCI  female             NaN
# 148  Process-rec-149        dev        HC    male            27.0
# 149  Process-rec-150        dev        HC    male            30.0
# 151  Process-rec-152        dev        HC  female            29.0
#
#                                                     TF  \
# 1    {'pat': 0.02040816326530612, '1': 0.0816326530...
# 3    {'pat': 0.016129032258064516, 'um': 0.09677419...
# 6    {'pat': 0.010752688172043012, 'goat': 0.010752...
# 7    {'pat': 0.01818181818181818, 'giraffe': 0.0181...
# 15   {'pat': 0.017857142857142856, '2': 0.053571428...
# 20   {'pat': 0.007518796992481203, 'dog': 0.0075187...
# 21   {'pat': 0.01639344262295082, 'antelope': 0.016...
# 31   {'pat': 0.05660377358490566, 'rabbit': 0.00943...
# 32   {'pat': 0.017543859649122806, 'cat': 0.0175438...
# 34   {'pat': 0.047619047619047616, 'cat': 0.0158730...
# 35   {'pat': 0.013513513513513514, 'dog': 0.0270270...
# 41   {'pat': 0.016666666666666666, 'dog': 0.0166666...
# 45   {'pat': 0.018518518518518517, 'cat': 0.0370370...
# 49   {'pat': 0.037037037037037035, '7': 0.037037037...
# 54   {'pat': 0.010309278350515464, 'dog': 0.0103092...
# 60   {'pat': 0.008620689655172414, 'aardvark': 0.00...
# 63   {'pat': 0.016666666666666666, 'dog': 0.0166666...
# 68   {'pat': 0.017857142857142856, 'cat': 0.0178571...
# 74   {'pat': 0.016666666666666666, 'horse': 0.01666...
# 75   {'pat': 0.010752688172043012, 'cat': 0.0107526...
# 77   {'pat': 0.021739130434782608, 'cat': 0.0217391...
# 79   {'pat': 0.011764705882352941, 'lion': 0.011764...
# 82   {'pat': 0.009433962264150943, 'ape': 0.0094339...
# 84   {'pat': 0.014285714285714285, 'aardvark': 0.01...
# 87   {'pat': 0.03571428571428571, 'dog': 0.03571428...
# 92   {'pat': 0.015384615384615385, 'um': 0.24615384...
# 103  {'pat': 0.02564102564102564, 'er': 0.025641025...
# 109  {'pat': 0.018867924528301886, 'sighs': 0.01886...
# 111  {'pat': 0.015873015873015872, 'cat': 0.0158730...
# 116  {'pat': 0.01694915254237288, 'dog': 0.01694915...
# 119  {'pat': 0.017857142857142856, 'cat': 0.0178571...
# 121  {'pat': 0.01694915254237288, 'giraffe': 0.0169...
# 128  {'pat': 0.02127659574468085, 'horse': 0.021276...
# 129  {'pat': 0.010752688172043012, 'cow': 0.0107526...
# 137  {'pat': 0.015151515151515152, 'buzzer': 0.0303...
# 140  {'pat': 0.015873015873015872, 'dog': 0.0158730...
# 143  {'pat': 0.012345679012345678, '2': 0.024691358...
# 148  {'pat': 0.012658227848101266, 'buzzer': 0.0253...
# 149  {'pat': 0.016666666666666666, 'buzzer': 0.0333...
# 151  {'pat': 0.019230769230769232, 'dog': 0.0192307...
#
#                                                    IDF
# 1    {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 3    {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 6    {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 7    {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 15   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 20   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 21   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 31   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 32   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 34   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 35   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 41   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 45   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 49   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 54   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 60   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 63   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 68   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 74   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 75   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 77   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 79   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 82   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 84   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 87   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 92   {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 103  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 109  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 111  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 116  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 119  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 121  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 128  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 129  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 137  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 140  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 143  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 148  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 149  {'rabbits': 2.5902671654458267, '5': 0.9808292...
# 151  {'rabbits': 2.5902671654458267, '5': 0.9808292...

# %%
result_df_dev.to_csv("TF-IDF_SFT_dev.csv", index = False)
