# %% [markdown]
# # Skript for Spectrogram Generation (images) #
#
# The dataset used for training and testing is the **PROCESS-V1** dataset, which can be downloaded here:
# [Download PROCESS-V1 Dataset](https://syncandshare.lrz.de/getlink/fiSPLrnFVFo3DvWqXkLGdY/PROCESS-V1_test.zip)
#
#
# - Only fully labeled data from the dataset is used for image grouping.
# - Setup using json file

# %%
import json

# Load variables from a JSON file
with open('config_image_creator.json') as f:
    config = json.load(f)

#print(config['data']['csv_file_path'])

# %%
import os
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
csv_file_path = config['data']['csv_file_path']  # Adjust this to your CSV file path
dem_info_df = pd.read_csv(csv_file_path)

# Define directories
base_dir = os.path.dirname(csv_file_path)  # Directory containing the CSV file and participant folders
output_dir = os.path.join(base_dir, config['data']['output_dir'])  # Folder to save spectrograms
os.makedirs(output_dir, exist_ok=True)

# Dynamically create subfolders based on unique classes in the CSV
class_dirs = {}
for class_label in dem_info_df['Class'].unique():
    class_dir = os.path.join(output_dir, class_label)
    os.makedirs(class_dir, exist_ok=True)
    class_dirs[class_label] = class_dir

# Function to generate and save spectrograms
def generate_spectrogram(audio_path, output_path, interval_duration=5):
    try:
        y, sr = librosa.load(audio_path, sr=None)
        total_duration = librosa.get_duration(y=y, sr=sr)

        # Generate spectrograms at x-second intervals
        for start_time in range(0, int(total_duration), interval_duration):
            end_time = start_time + interval_duration
            if end_time > total_duration:
                break
            y_segment = y[int(start_time * sr):int(end_time * sr)]
            D = librosa.amplitude_to_db(np.abs(librosa.stft(y_segment)), ref=np.max)

            # Save the spectrogram image
            plt.figure(figsize=(10, 4))
            librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='hz')
            plt.colorbar(format='%+2.0f dB')
            plt.title('Spectrogram')
            plt.tight_layout()

            # Save the spectrogram
            filename = os.path.basename(audio_path).replace('.wav', f'_start{start_time}s.png')
            plt.savefig(os.path.join(output_path, filename))
            plt.close()
    except Exception as e:
        print(f"Error processing {audio_path}: {e}")

# Iterate over the CSV records
for index, row in dem_info_df.iterrows():
    record_id = row['Record-ID']
    health_class = row['Class']

    participant_folder = os.path.join(base_dir, record_id)

    # Determine output folder based on class
    output_subfolder = class_dirs.get(health_class)
    if not output_subfolder:
        print(f"Unknown class {health_class} for Record-ID {record_id}. Skipping...")
        continue

    # Process WAV files in the participant folder
    if os.path.exists(participant_folder):
        for file_name in os.listdir(participant_folder):
            if file_name.endswith('.wav'):
                audio_path = os.path.join(participant_folder, file_name)
                generate_spectrogram(audio_path, output_subfolder, config['setup']['interval_duration'])
    else:
        print(f"Folder not found: {participant_folder}")
# Out:
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-115\Process-rec-115__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (158, 1024) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-117\Process-rec-117__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (158, 1024) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-117\Process-rec-117__PFT.wav: Unable to allocate 3.83 MiB for an array with shape (1003840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-119\Process-rec-119__CTD.wav: Unable to allocate 1.24 MiB for an array with shape (1025, 158) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-119\Process-rec-119__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-119\Process-rec-119__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__CTD.wav: Unable to allocate 4.29 MiB for an array with shape (1124800,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__PFT.wav: Unable to allocate 3.44 MiB for an array with shape (901760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__SFT.wav: Unable to allocate 3.52 MiB for an array with shape (923200,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__CTD.wav: Unable to allocate 4.93 MiB for an array with shape (1291840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__PFT.wav: Unable to allocate 3.34 MiB for an array with shape (874880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__SFT.wav: Unable to allocate 3.62 MiB for an array with shape (949280,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__CTD.wav: Unable to allocate 2.94 MiB for an array with shape (771200,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__PFT.wav: Unable to allocate 2.85 MiB for an array with shape (747840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__SFT.wav: Unable to allocate 3.67 MiB for an array with shape (962560,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__CTD.wav: Unable to allocate 4.77 MiB for an array with shape (1249920,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__PFT.wav: Unable to allocate 3.48 MiB for an array with shape (913280,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__SFT.wav: Unable to allocate 3.83 MiB for an array with shape (1003040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__CTD.wav: Unable to allocate 4.22 MiB for an array with shape (1107040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__PFT.wav: Unable to allocate 3.90 MiB for an array with shape (1021120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__SFT.wav: Unable to allocate 3.94 MiB for an array with shape (1032480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__CTD.wav: Unable to allocate 3.31 MiB for an array with shape (868960,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__PFT.wav: Unable to allocate 3.49 MiB for an array with shape (914400,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__SFT.wav: Unable to allocate 3.42 MiB for an array with shape (896640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__CTD.wav: Unable to allocate 2.15 MiB for an array with shape (564000,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__PFT.wav: Unable to allocate 2.90 MiB for an array with shape (759200,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__SFT.wav: Unable to allocate 2.86 MiB for an array with shape (748480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__CTD.wav: Unable to allocate 1.25 MiB for an array with shape (326400,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__PFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__SFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__CTD.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__CTD.wav: Unable to allocate 5.56 MiB for an array with shape (1457760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__PFT.wav: Unable to allocate 3.74 MiB for an array with shape (979360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__SFT.wav: Unable to allocate 3.83 MiB for an array with shape (1004640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__PFT.wav: Unable to allocate 3.98 MiB for an array with shape (1044480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__SFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__CTD.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__CTD.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__PFT.wav: Unable to allocate 1.01 MiB for an array with shape (1062080,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__CTD.wav: Unable to allocate 9.34 MiB for an array with shape (2448160,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__CTD.wav: Unable to allocate 4.91 MiB for an array with shape (1025, 157, 4) and data type float64
# C:\Users\Peter\AppData\Local\Temp\ipykernel_23316\1135845642.py:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 4))
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__PFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__SFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__CTD.wav: Unable to allocate 10.1 MiB for an array with shape (2649760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__PFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__CTD.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__CTD.wav: Unable to allocate 1.00 MiB for an array with shape (1051680,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__CTD.wav: Unable to allocate 4.62 MiB for an array with shape (1211520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__SFT.wav: Unable to allocate 3.78 MiB for an array with shape (991040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__PFT.wav: Unable to allocate 3.86 MiB for an array with shape (1011840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__SFT.wav: Unable to allocate 4.32 MiB for an array with shape (1132960,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type int64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__PFT.wav: Unable to allocate 1.05 MiB for an array with shape (1098080,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__CTD.wav: Unable to allocate 4.91 MiB for an array with shape (1288160,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__PFT.wav: Unable to allocate 1.10 MiB for an array with shape (1149280,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__CTD.wav: Unable to allocate 10.2 MiB for an array with shape (2675200,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__CTD.wav: Unable to allocate 8.24 MiB for an array with shape (2160800,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__SFT.wav: Unable to allocate 3.90 MiB for an array with shape (1023360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__CTD.wav: Unable to allocate 4.09 MiB for an array with shape (1071360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__CTD.wav: Unable to allocate 6.08 MiB for an array with shape (1593600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__PFT.wav: Unable to allocate 4.04 MiB for an array with shape (1059360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__SFT.wav: Unable to allocate 3.90 MiB for an array with shape (1021600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__CTD.wav: Unable to allocate 6.09 MiB for an array with shape (1595295,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__SFT.wav: Unable to allocate 4.06 MiB for an array with shape (1064000,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__CTD.wav: Unable to allocate 10.1 MiB for an array with shape (2635520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__PFT.wav: Unable to allocate 1022. KiB for an array with shape (1046880,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__SFT.wav: Unable to allocate 1.03 MiB for an array with shape (1074880,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__CTD.wav: Unable to allocate 4.85 MiB for an array with shape (1272696,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__PFT.wav: Unable to allocate 1.03 MiB for an array with shape (1076640,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__SFT.wav: Unable to allocate 1.07 MiB for an array with shape (1122880,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__PFT.wav: Unable to allocate 1.01 MiB for an array with shape (1061120,) and data type bool
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__PFT.wav: Unable to allocate 3.82 MiB for an array with shape (1002240,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__SFT.wav: Unable to allocate 4.15 MiB for an array with shape (1086880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__CTD.wav: Unable to allocate 7.42 MiB for an array with shape (1945120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__PFT.wav: Unable to allocate 3.88 MiB for an array with shape (1018400,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__SFT.wav: Unable to allocate 4.02 MiB for an array with shape (1054400,) and data type float32
# Error in callback <function _draw_all_if_interactive at 0x00000249F747A2A0> (for post_execute), with arguments args (),kwargs {}:

# %% [markdown]
# # Deprecated (2 classes): #

# %%
import os
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
csv_file_path = r'F:\Peter\ML_exp\PROCESS-V1\dem-info.csv'  # Adjust this to your CSV file path
dem_info_df = pd.read_csv(csv_file_path)

# Define directories
base_dir = os.path.dirname(csv_file_path)  # Directory containing the CSV file and participant folders
output_dir = os.path.join(base_dir, "Spectrograms")  # Folder to save spectrograms
os.makedirs(output_dir, exist_ok=True)

# Create subfolders for classification
healthy_dir = os.path.join(output_dir, "Healthy")
not_healthy_dir = os.path.join(output_dir, "Not Healthy")
os.makedirs(healthy_dir, exist_ok=True)
os.makedirs(not_healthy_dir, exist_ok=True)

# Classification parameters
classification_column = 'Class'
mmse_column = 'Converted-MMSE'

# Fix numpy compatibility for librosa
np.complex = np.complex128  # Temporary fix for deprecated attribute

# Function to generate and save spectrograms
def generate_spectrogram(audio_path, output_path, interval_duration=5):
    try:
        y, sr = librosa.load(audio_path, sr=None)
        total_duration = librosa.get_duration(y=y, sr=sr)

        # Generate spectrograms at 5-second intervals
        for start_time in range(0, int(total_duration), interval_duration):
            end_time = start_time + interval_duration
            if end_time > total_duration:
                break
            y_segment = y[int(start_time * sr):int(end_time * sr)]
            D = librosa.amplitude_to_db(np.abs(librosa.stft(y_segment)), ref=np.max)

            # Save the spectrogram image
            plt.figure(figsize=(10, 4))
            librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='hz')
            plt.colorbar(format='%+2.0f dB')
            plt.title('Spectrogram')
            plt.tight_layout()

            # Save with MMSE score in filename
            filename = os.path.basename(audio_path).replace('.wav', f'_start{start_time}s.png')
            plt.savefig(os.path.join(output_path, filename))
            plt.close()
    except Exception as e:
        print(f"Error processing {audio_path}: {e}")

# Iterate over the CSV records
for index, row in dem_info_df.iterrows():
    record_id = row['Record-ID']
    health_class = row[classification_column]
    mmse_score = row[mmse_column]

    participant_folder = os.path.join(base_dir, record_id)

    # Determine output subfolder
    output_subfolder = healthy_dir if health_class == "HC" else not_healthy_dir

    # Process WAV files in the participant folder
    if os.path.exists(participant_folder):
        for file_name in os.listdir(participant_folder):
            if file_name.endswith('.wav'):
                audio_path = os.path.join(participant_folder, file_name)
                generate_spectrogram(audio_path, output_subfolder)
    else:
        print(f"Folder not found: {participant_folder}")
# Out:
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-119\Process-rec-119__PFT.wav: Unable to allocate 4.91 MiB for an array with shape (1025, 157, 4) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-119\Process-rec-119__SFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__PFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-120\Process-rec-120__SFT.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-121\Process-rec-121__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__PFT.wav: Unable to allocate 2.85 MiB for an array with shape (747840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-122\Process-rec-122__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__CTD.wav: Unable to allocate 4.77 MiB for an array with shape (1249920,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-123\Process-rec-123__SFT.wav: Unable to allocate 3.83 MiB for an array with shape (1003040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__CTD.wav: Unable to allocate 4.22 MiB for an array with shape (1107040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__PFT.wav: Unable to allocate 3.90 MiB for an array with shape (1021120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-124\Process-rec-124__SFT.wav: Unable to allocate 3.94 MiB for an array with shape (1032480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__CTD.wav: Unable to allocate 3.31 MiB for an array with shape (868960,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__PFT.wav: Unable to allocate 3.49 MiB for an array with shape (914400,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-125\Process-rec-125__SFT.wav: Unable to allocate 3.42 MiB for an array with shape (896640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-126\Process-rec-126__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__PFT.wav: Unable to allocate 3.26 MiB for an array with shape (854080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-127\Process-rec-127__SFT.wav: Unable to allocate 3.29 MiB for an array with shape (862240,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__CTD.wav: Unable to allocate 2.63 MiB for an array with shape (689600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__PFT.wav: Unable to allocate 3.61 MiB for an array with shape (946080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-128\Process-rec-128__SFT.wav: Unable to allocate 3.58 MiB for an array with shape (938560,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__CTD.wav: Unable to allocate 5.56 MiB for an array with shape (1457760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__PFT.wav: Unable to allocate 2.87 MiB for an array with shape (751520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-129\Process-rec-129__SFT.wav: Unable to allocate 3.25 MiB for an array with shape (851520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__CTD.wav: Unable to allocate 2.52 MiB for an array with shape (661440,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__PFT.wav: Unable to allocate 3.74 MiB for an array with shape (979360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-130\Process-rec-130__SFT.wav: Unable to allocate 3.83 MiB for an array with shape (1004640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__CTD.wav: Unable to allocate 3.20 MiB for an array with shape (838720,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__PFT.wav: Unable to allocate 3.98 MiB for an array with shape (1044480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-131\Process-rec-131__SFT.wav: Unable to allocate 3.98 MiB for an array with shape (1044480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__CTD.wav: Unable to allocate 3.76 MiB for an array with shape (985120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__PFT.wav: Unable to allocate 4.33 MiB for an array with shape (1134080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-132\Process-rec-132__SFT.wav: Unable to allocate 4.33 MiB for an array with shape (1134080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__CTD.wav: Unable to allocate 1.90 MiB for an array with shape (497280,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__PFT.wav: Unable to allocate 4.05 MiB for an array with shape (1062080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-133\Process-rec-133__SFT.wav: Unable to allocate 3.89 MiB for an array with shape (1020000,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__CTD.wav: Unable to allocate 9.34 MiB for an array with shape (2448160,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__PFT.wav: Unable to allocate 4.06 MiB for an array with shape (1065120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-134\Process-rec-134__SFT.wav: Unable to allocate 3.91 MiB for an array with shape (1025440,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__CTD.wav: Unable to allocate 2.20 MiB for an array with shape (577600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__PFT.wav: Unable to allocate 3.69 MiB for an array with shape (966720,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-135\Process-rec-135__SFT.wav: Unable to allocate 3.83 MiB for an array with shape (1004960,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__CTD.wav: Unable to allocate 10.1 MiB for an array with shape (2649760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__PFT.wav: Unable to allocate 3.70 MiB for an array with shape (968800,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-136\Process-rec-136__SFT.wav: Unable to allocate 3.87 MiB for an array with shape (1013760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__CTD.wav: Unable to allocate 1.89 MiB for an array with shape (495520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__PFT.wav: Unable to allocate 3.71 MiB for an array with shape (972480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-137\Process-rec-137__SFT.wav: Unable to allocate 3.81 MiB for an array with shape (999680,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__CTD.wav: Unable to allocate 2.99 MiB for an array with shape (784640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__PFT.wav: Unable to allocate 3.88 MiB for an array with shape (1017280,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-138\Process-rec-138__SFT.wav: Unable to allocate 3.76 MiB for an array with shape (985600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__CTD.wav: Unable to allocate 4.01 MiB for an array with shape (1051680,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__PFT.wav: Unable to allocate 3.70 MiB for an array with shape (970240,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-139\Process-rec-139__SFT.wav: Unable to allocate 3.72 MiB for an array with shape (974880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__CTD.wav: Unable to allocate 4.62 MiB for an array with shape (1211520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__PFT.wav: Unable to allocate 3.69 MiB for an array with shape (968320,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-140\Process-rec-140__SFT.wav: Unable to allocate 3.78 MiB for an array with shape (991040,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__CTD.wav: Unable to allocate 1.66 MiB for an array with shape (434080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__PFT.wav: Unable to allocate 3.86 MiB for an array with shape (1011840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-141\Process-rec-141__SFT.wav: Unable to allocate 4.32 MiB for an array with shape (1132960,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__CTD.wav: Unable to allocate 1.22 MiB for an array with shape (1025, 156) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__PFT.wav: Unable to allocate 4.19 MiB for an array with shape (1098080,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-142\Process-rec-142__SFT.wav: Unable to allocate 3.80 MiB for an array with shape (996480,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__CTD.wav: Unable to allocate 4.91 MiB for an array with shape (1288160,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__PFT.wav: Unable to allocate 4.38 MiB for an array with shape (1149280,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-143\Process-rec-143__SFT.wav: Unable to allocate 3.79 MiB for an array with shape (993616,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__CTD.wav: Unable to allocate 3.26 MiB for an array with shape (855680,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__PFT.wav: Unable to allocate 3.84 MiB for an array with shape (1007840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-144\Process-rec-144__SFT.wav: Unable to allocate 3.84 MiB for an array with shape (1007360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__PFT.wav: Unable to allocate 3.74 MiB for an array with shape (980320,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-145\Process-rec-145__SFT.wav: Unable to allocate 3.65 MiB for an array with shape (956000,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type int64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type int64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-146\Process-rec-146__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__CTD.wav: Unable to allocate 8.24 MiB for an array with shape (2160800,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-147\Process-rec-147__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__CTD.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-148\Process-rec-148__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__CTD.wav: Unable to allocate 4.09 MiB for an array with shape (1071360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-149\Process-rec-149__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__CTD.wav: Unable to allocate 6.08 MiB for an array with shape (1593600,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-150\Process-rec-150__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__CTD.wav: Unable to allocate 6.09 MiB for an array with shape (1595295,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__PFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type float64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-151\Process-rec-151__SFT.wav: Unable to allocate 1.23 MiB for an array with shape (1025, 157) and data type complex64
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__CTD.wav: Unable to allocate 10.1 MiB for an array with shape (2635520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__PFT.wav: Unable to allocate 3.99 MiB for an array with shape (1046880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-152\Process-rec-152__SFT.wav: Unable to allocate 3.68 MiB for an array with shape (963840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__CTD.wav: Unable to allocate 2.70 MiB for an array with shape (706720,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__PFT.wav: Unable to allocate 3.67 MiB for an array with shape (963360,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-153\Process-rec-153__SFT.wav: Unable to allocate 4.10 MiB for an array with shape (1074880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__CTD.wav: Unable to allocate 4.85 MiB for an array with shape (1272696,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__PFT.wav: Unable to allocate 4.11 MiB for an array with shape (1076640,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-154\Process-rec-154__SFT.wav: Unable to allocate 4.28 MiB for an array with shape (1122880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__CTD.wav: Unable to allocate 2.36 MiB for an array with shape (619520,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__PFT.wav: Unable to allocate 4.05 MiB for an array with shape (1061120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-155\Process-rec-155__SFT.wav: Unable to allocate 3.93 MiB for an array with shape (1029760,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__CTD.wav: Unable to allocate 2.65 MiB for an array with shape (695840,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__PFT.wav: Unable to allocate 3.82 MiB for an array with shape (1002240,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-156\Process-rec-156__SFT.wav: Unable to allocate 4.15 MiB for an array with shape (1086880,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__CTD.wav: Unable to allocate 7.42 MiB for an array with shape (1945120,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__PFT.wav: Unable to allocate 3.88 MiB for an array with shape (1018400,) and data type float32
# Error processing F:\Peter\ML_exp\PROCESS-V1\Process-rec-157\Process-rec-157__SFT.wav: Unable to allocate 4.02 MiB for an array with shape (1054400,) and data type float32
# Error in callback <function _draw_all_if_interactive at 0x000002292C245300> (for post_execute), with arguments args (),kwargs {}:
